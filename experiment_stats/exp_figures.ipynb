# %%
from statistics import mean
import matplotlib.pyplot as plt
colors = ['blue', 'orange', 'green', 'red']

# %%
sys_in_per_worker_tp = [1000, 4000, 16000, 64000, 96000]
in_per_worker_tp = [1000, 4000, 16000]
in_tp = [str(i*4) for i in in_per_worker_tp]
sys_in_tp = [str(i*4) for i in sys_in_per_worker_tp]
q3_alo_p50 = [133,
155.8,
117.7,
130.4, 150.6]
q3_epoch_p50 = [
158.7,
162.2,
133.6,
137.8, 204.0]
q3_kafka_alo_p50 = [
    179.6,
203,
155.7,
892.4,]
q3_kafka_eo_p50 = [
    275.2,
305.5,
194.4,
21041.8,]
q3_kafka_nocache_alo_p50 = [115.9,
110.1,
84.3,
28881]
q3_kafka_nocache_eo_p50 = [175.1,
180.1,
105.2,
24166.4]
q3_alo_p99 = [
264.2,
275.9,
210.9,
214.6, 275.4]
q3_epoch_p99 = [
284.4,
292.8,
234.1,
244.8, 341.7]
q3_kafka_alo_p99 = [
    351.6,
310.4,
454.5,
3586.1,]
q3_kafka_eo_p99 = [
    444.2,
461.4,
480.8,
23896.1,]
q3_kafka_nocache_alo_p99 = [201.4,
194.4,
414,
36686.2]
q3_kafka_nocache_eo_p99 = [296.3,
295.7,
527.1,
26570.2]
# fig = plt.figure(figsize=(6, 7))
# ax1 = plt.subplot(211)
# l1, = ax1.plot(in_tp, q3_alo_p50, label='sys(at least once) p50', color=colors[0])
# l2, = ax1.plot(in_tp, q3_epoch_p50, label='sys(epoch) p50', color=colors[1])
# l3, = ax1.plot(in_tp, q3_kafka_nocache_alo_p50, label='kafka(at least once) p50', color=colors[2])
# l4, = ax1.plot(in_tp, q3_kafka_nocache_eo_p50, label='kafka(exactly once) p50', color=colors[3])
# ax2 = plt.subplot(212)
# l5, = ax2.plot(in_tp, q3_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
# l6, = ax2.plot(in_tp, q3_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
# l7, = ax2.plot(in_tp, q3_kafka_nocache_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
# l8, = ax2.plot(in_tp, q3_kafka_nocache_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])
# 
# ax2.set_xlabel('input throughput(events/s)')
# ax1.set_ylabel('event time latency(ms)')
# ax2.set_ylabel('event time latency(ms)')
# ax1.legend(loc=(0, 1.1),ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
# plt.savefig('q3.pdf', bbox_inches='tight')

# fig = plt.figure()
# plt.plot(in_tp, q3_alo_p50[:-1], label='sys(at least once) p50', color=colors[0])
# plt.plot(in_tp, q3_epoch_p50[:-1], label='sys(epoch) p50', color=colors[1])
# plt.plot(in_tp, q3_kafka_nocache_alo_p50[:-1], label='kafka(at least once) p50', color=colors[2])
# plt.plot(in_tp, q3_kafka_nocache_eo_p50[:-1], label='kafka(exactly once) p50', color=colors[3])
# plt.plot(in_tp, q3_alo_p99[:-1], label='sys(at least once) p99', ls='--', color=colors[0])
# plt.plot(in_tp, q3_epoch_p99[:-1], label='sys(epoch) p99', ls='--', color=colors[1])
# plt.plot(in_tp, q3_kafka_nocache_alo_p99[:-1], label='kafka(at least once) p99', ls='--', color=colors[2])
# plt.plot(in_tp, q3_kafka_nocache_eo_p99[:-1], label='kafka(exactly once) p99', ls='--', color=colors[3])
# 
# plt.xlabel('input throughput(events/s)')
# plt.ylabel('event time latency(ms)')
# plt.legend(loc=(0, 1.1),ncol=2)
# plt.savefig('q3.pdf', bbox_inches='tight')

fig = plt.figure(figsize=(6, 7))
ax1 = plt.subplot(211)
l1, = ax1.plot(sys_in_tp, q3_alo_p50, label='sys(at least once) p50', color=colors[0])
l2, = ax1.plot(in_tp, q3_kafka_nocache_alo_p50[:-1], label='kafka(at least once) p50', color=colors[2])
l3, = ax1.plot(sys_in_tp, q3_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
l4, = ax1.plot(in_tp, q3_kafka_nocache_alo_p99[:-1], label='kafka(at least once) p99', ls='--', color=colors[2])
ax2 = plt.subplot(212)
l5, = ax2.plot(sys_in_tp, q3_epoch_p50, label='sys(epoch) p50', color=colors[1])
l6, = ax2.plot(in_tp, q3_kafka_nocache_eo_p50[:-1], label='kafka(exactly once) p50', color=colors[3])
l7, = ax2.plot(sys_in_tp, q3_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
l8, = ax2.plot(in_tp, q3_kafka_nocache_eo_p99[:-1], label='kafka(exactly once) p99', ls='--', color=colors[3])

ax2.set_xlabel('input throughput(events/s)')
ax1.set_ylabel('event time latency(ms)')
ax2.set_ylabel('event time latency(ms)')
ax1.legend(loc=(0, 1.1),ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
plt.savefig('q3_split.pdf', bbox_inches='tight')

# %%
in_per_worker_tp = [125, 250, 500]
in_tp = [str(i*4) for i in in_per_worker_tp]
q4_alo_p50 =  [190.5, 172.9, 164]
q4_epoch_p50 = [117.5, 108.8, 112.3]
q4_cache_alo_p50 = [164.0, 129.9, 124.0]
q4_cache_epoch_p50 =  [127.5, 111.3, 115.6]
q4_kafka_alo_p50 = [
    193.4,
177.7,
187.3,
]
q4_kafka_eo_p50 = [
    289.1,
301.2,
346.3,
]
q4_kafka_nocache_alo_p50 = [193.3,
163.7,
183.2]
q4_kafka_nocache_eo_p50 = [314.8,
283.1,
372.9]
q4_alo_p99 = [330.3, 305.0, 309.8]
q4_epoch_p99 = [217.6, 194.3, 226.4]
q4_cache_alo_p99 = [305.6, 263.1, 254.0]
q4_cache_epoch_p99 = [230.6, 205.8, 215.8]
q4_kafka_alo_p99 = [
    313.6,
292.9,
293.7,
]
q4_kafka_eo_p99 = [
    422.3,
418.4,
472.1,
]
q4_kafka_nocache_alo_p99 = [308.2,
253.3,
281.2]
q4_kafka_nocache_eo_p99 = [445.8,
422.5,
525.8]
plt.figure()
plt.plot(in_tp, q4_alo_p50, label='sys(at least once) p50', color=colors[0])
plt.plot(in_tp, q4_epoch_p50, label='sys(epoch) p50', color=colors[1])
plt.plot(in_tp, q4_kafka_nocache_alo_p50, label='kafka(at least once) p50', color=colors[2])
plt.plot(in_tp, q4_kafka_nocache_eo_p50, label='kafka(exactly once) p50', color=colors[3])
plt.plot(in_tp, q4_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
plt.plot(in_tp, q4_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
plt.plot(in_tp, q4_kafka_nocache_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
plt.plot(in_tp, q4_kafka_nocache_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

plt.xlabel('input throughput(events/s)')
plt.ylabel('event time latency(ms)')
plt.legend(loc=(0, 1.02), ncol=2)
plt.savefig('q4.pdf', bbox_inches='tight')

plt.figure(figsize=(6,7))
ax1 = plt.subplot(211)
l1, = ax1.plot(in_tp, q4_cache_alo_p50, label='sys(at least once) p50', color=colors[0])
l2, = ax1.plot(in_tp, q4_kafka_alo_p50, label='kafka(at least once) p50', color=colors[2])
l3, = ax1.plot(in_tp, q4_cache_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
l4, = ax1.plot(in_tp, q4_kafka_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
# ax1.set_xlabel('input throughput(events/s)')
ax1.set_ylabel('event time latency(ms)')

ax2 = plt.subplot(212)
l5, = ax2.plot(in_tp, q4_cache_epoch_p50, label='sys(epoch) p50', color=colors[1])
l6, = ax2.plot(in_tp, q4_kafka_eo_p50, label='kafka(exactly once) p50', color=colors[3])
l7, = ax2.plot(in_tp, q4_cache_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
l8, = ax2.plot(in_tp, q4_kafka_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])
ax2.set_xlabel('input throughput(events/s)')
ax2.set_ylabel('event time latency(ms)')

ax1.legend(loc=(0, 1.02), ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
plt.savefig('q4_split.pdf', bbox_inches='tight')

# %%
in_per_worker_tp = [1000, 2000, 4000, 8000]
sys_in_per_worker_tp = [1000, 2000, 4000, 8000, 16000]
in_tp = [str(i*4) for i in in_per_worker_tp]
sys_in_tp = [str(i*4) for i in sys_in_per_worker_tp]
q5_alo_p50 = [171.6,
173.7,
148.8,
103.7,
103.2]
q5_epoch_p50 = [151.7,
197.2,
187,
189.2,
234.7]
q5_cache_alo_p50 = [56.4, 68.5, 61.8, 80.2, 67.6]
q5_cache_epoch_p50 = [44.8, 78.7, 97.8, 114, 94.3] 
q5_kafka_alo_p50 = [141.4,
153.9,
166.1,
143.2,]
q5_kafka_eo_p50 = [213.8,
227.3,
250.3,
221.3,]
q5_kafka_nocache_alo_p50 = [159.8,
187.2,
204.9,
592.2]
q5_kafka_nocache_eo_p50 = [312.2,
319.3,
364.4,
1160.8]
q5_alo_p99 = [304.2,
323.9,
311.4,
250,
211.5]
q5_epoch_p99 = [287.6,
331.3,
331.7,
303,
360]
q5_cache_alo_p99 =  [396.4, 385.2, 363.8, 308.6, 258.6]
q5_cache_epoch_p99 = [382, 397.1, 385, 318.5, 271.7]
q5_kafka_alo_p99 = [256.7,
297.8,
327,
496.9,]
q5_kafka_eo_p99 = [370.2,
396.1,
422.5,
882.8,]
q5_kafka_nocache_alo_p99 = [278.8,
332.3,
396,
1656.7]
q5_kafka_nocache_eo_p99 = [468.4,
492.3,
838.6,
2714.6]
plt.figure()
plt.plot(sys_in_tp, q5_alo_p50, label='sys(at least once) p50', color=colors[0])
plt.plot(sys_in_tp, q5_epoch_p50, label='sys(epoch) p50', color=colors[1])
plt.plot(in_tp, q5_kafka_nocache_alo_p50, label='kafka(at least once) p50', color=colors[2])
plt.plot(in_tp, q5_kafka_nocache_eo_p50, label='kafka(exactly once) p50', color=colors[3])
plt.plot(sys_in_tp, q5_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
plt.plot(sys_in_tp, q5_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
plt.plot(in_tp, q5_kafka_nocache_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
plt.plot(in_tp, q5_kafka_nocache_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

plt.xlabel('input throughput(events/s)')
plt.ylabel('event time latency(ms)')
plt.legend(loc=(0, 1.02), ncol=2)
plt.savefig('q5.pdf', bbox_inches='tight')

plt.figure(figsize=(6, 7))
ax1 = plt.subplot(211)
l1, = ax1.plot(sys_in_tp, q5_cache_alo_p50, label='sys(at least once) p50', color=colors[0])
l2, = ax1.plot(in_tp, q5_kafka_alo_p50, label='kafka(at least once) p50', color=colors[2])
l3, = ax1.plot(sys_in_tp, q5_cache_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
l4, = ax1.plot(in_tp, q5_kafka_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])

ax2 = plt.subplot(212)
l5, = ax2.plot(sys_in_tp, q5_cache_epoch_p50, label='sys(epoch) p50', color=colors[1])
l6, = ax2.plot(in_tp, q5_kafka_eo_p50, label='kafka(exactly once) p50', color=colors[3])
l7, = ax2.plot(sys_in_tp, q5_cache_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
l8, = ax2.plot(in_tp, q5_kafka_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

ax2.set_xlabel('input throughput(events/s)')
ax1.set_ylabel('event time latency(ms)')
ax2.set_ylabel('event time latency(ms)')
ax1.legend(loc=(0, 1.02), ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
plt.savefig('q5_split.pdf', bbox_inches='tight')

# %%
in_per_worker_tp = [125, 250, 500]
in_tp = [str(i*4) for i in in_per_worker_tp]
q6_alo_p50 = [225.3, 218.4, 204.3]
q6_epoch_p50 = [148.1, 141.6, 164.1]
q6_cache_alo_p50 =  [214.4, 190.9, 173.8]
q6_cache_epoch_p50 = [165.6, 157.1, 155.7]
q6_kafka_alo_p50 = [221.7,
207.4,
228.1,]
q6_kafka_eo_p50 = [320.3,
346.7,
389,]
q6_kafka_nocache_alo_p50 = [229.3,
205,
235.5]
q6_kafka_nocache_eo_p50 = [309.7,
343.6,
411.5]
q6_alo_p99 = [414.0, 414.0, 387.8]
q6_epoch_p99 = [297.3, 299.4, 368.7]
q6_cache_alo_p99 =  [445.3, 416.2, 435.7]
q6_cache_epoch_p99 = [333.6, 328.7, 375.4]
q6_kafka_alo_p99 = [379.2,
369.6,
400.1,]
q6_kafka_eo_p99 = [458.2,
478.6,
550.8,]
q6_kafka_nocache_alo_p99 = [382.6,
348.4,
390.7]
q6_kafka_nocache_eo_p99 = [466,
525.7,
629.9]
plt.figure()
plt.plot(in_tp, q6_alo_p50, label='sys(at least once) p50', color=colors[0])
plt.plot(in_tp, q6_epoch_p50, label='sys(epoch) p50', color=colors[1])
plt.plot(in_tp, q6_kafka_nocache_alo_p50, label='kafka(at least once) p50', color=colors[2])
plt.plot(in_tp, q6_kafka_nocache_eo_p50, label='kafka(exactly once) p50', color=colors[3])
plt.plot(in_tp, q6_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
plt.plot(in_tp, q6_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
plt.plot(in_tp, q6_kafka_nocache_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
plt.plot(in_tp, q6_kafka_nocache_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

plt.xlabel('input throughput(events/s)')
plt.ylabel('event time latency(ms)')
plt.legend(loc=(0, 1.02), ncol=2)
plt.savefig('q6.pdf', bbox_inches='tight')

plt.figure(figsize=(6,7))
ax1 = plt.subplot(211)
l1, = ax1.plot(in_tp, q6_cache_alo_p50, label='sys(at least once) p50', color=colors[0])
l2, = ax1.plot(in_tp, q6_kafka_alo_p50, label='kafka(at least once) p50', color=colors[2])
l3, = ax1.plot(in_tp, q6_cache_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
l4, = ax1.plot(in_tp, q6_kafka_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])

ax2 = plt.subplot(212)
l5, = ax2.plot(in_tp, q6_cache_epoch_p50, label='sys(epoch) p50', color=colors[1])
l6, = ax2.plot(in_tp, q6_kafka_eo_p50, label='kafka(exactly once) p50', color=colors[3])
l7, = ax2.plot(in_tp, q6_cache_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
l8, = ax2.plot(in_tp, q6_kafka_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

ax2.set_xlabel('input throughput(events/s)')
ax1.set_ylabel('event time latency(ms)')
ax2.set_ylabel('event time latency(ms)')
ax1.legend(loc=(0, 1.02), ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
plt.savefig('q6_split.pdf', bbox_inches='tight')

# %%
in_per_worker_tp = [125, 250, 500]
in_tp = [str(i*4) for i in in_per_worker_tp]
sys_per_worker_tp = [125, 250, 500, 1000, 2000, 4000]
sys_in_tp = [str(i*4) for i in sys_per_worker_tp]

q7_alo_p50 = [117.8, 131.9, 145.8]
q7_epoch_p50 = [140.6, 137, 214.4]
q7_cache_alo_p50 = [68.8, 64.3, 58.8, 62.9, 59.4, 106.5]
q7_cache_epoch_p50 = [67.2, 64.7, 63.3, 65.2, 66.5, 128.3]
q7_kafka_alo_p50 = [81.5,
97.8,
109,57.3, 72.9, 75.6]
q7_kafka_eo_p50 = [121.3,
143.6,
193.4,51.0, 70.9, 72.9]
q7_kafka_nocache_alo_p50 = [132.8,
143,
156.1]
q7_kafka_nocache_eo_p50 = [172.9,
195,
266.5]
q7_alo_p99 = [242.8, 241.3, 273.2]
q7_epoch_p99 = [314.5, 294.6, 415.3]
q7_cache_alo_p99 = [291.1, 417.3, 535.5, 487.2, 381.7, 392.3]
q7_cache_epoch_p99 = [457.1, 409.9, 393.5, 560.0, 534.6, 484.5]
q7_kafka_alo_p99 = [195.2,
213,
223,141.8, 176.9, 225.5]
q7_kafka_eo_p99 = [257.6,
287.4,
333.8,145.8, 160.8, 193.3]
q7_kafka_nocache_alo_p99 = [222,
235.3,
242.9]
q7_kafka_nocache_eo_p99 = [318.4,
332.7,
401.6]

plt.figure()
plt.plot(in_tp, q7_alo_p50, label='sys(at least once) p50', color=colors[0])
plt.plot(in_tp, q7_epoch_p50, label='sys(epoch) p50', color=colors[1])
plt.plot(in_tp, q7_kafka_nocache_alo_p50, label='kafka(at least once) p50', color=colors[2])
plt.plot(in_tp, q7_kafka_nocache_eo_p50, label='kafka(exactly once) p50', color=colors[3])
plt.plot(in_tp, q7_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
plt.plot(in_tp, q7_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
plt.plot(in_tp, q7_kafka_nocache_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
plt.plot(in_tp, q7_kafka_nocache_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

plt.xlabel('input throughput(events/s)')
plt.ylabel('event time latency(ms)')
plt.legend(loc=(0, 1.02), ncol=2)
plt.savefig('q7.pdf', bbox_inches='tight')

plt.figure(figsize=(6, 7))
ax1 = plt.subplot(211)
l1, = ax1.plot(sys_in_tp, q7_cache_alo_p50, label='sys(at least once) p50', color=colors[0])
l2, = ax1.plot(sys_in_tp, q7_kafka_alo_p50, label='kafka(at least once) p50', color=colors[2])
l3, = ax1.plot(sys_in_tp, q7_cache_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
l4, = ax1.plot(sys_in_tp, q7_kafka_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])

ax2 = plt.subplot(212)
l5, = ax2.plot(sys_in_tp, q7_cache_epoch_p50, label='sys(epoch) p50', color=colors[1])
l6, = ax2.plot(sys_in_tp, q7_kafka_eo_p50, label='kafka(exactly once) p50', color=colors[3])
l7, = ax2.plot(sys_in_tp, q7_cache_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
l8, = ax2.plot(sys_in_tp, q7_kafka_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

ax2.set_xlabel('input throughput(events/s)')
ax1.set_ylabel('event time latency(ms)')
ax2.set_ylabel('event time latency(ms)')
ax1.legend(loc=(0, 1.02), ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
plt.savefig('q7_split.pdf', bbox_inches='tight')

# %%
in_per_worker_tp = [500, 1000, 2000, 4000, 8000]
in_tp = [str(i*4) for i in in_per_worker_tp]
q8_alo_p50 = [165.5,
142.2,
146.2,
150.2,
137.3,
168.8]
q8_epoch_p50 = [163.1,
167,
168.3,
173.5,
177.4,
4534.7]
q8_kafka_alo_p50 = [115.6,
107.8,
111.7,
113.3,
102.9,
134.1]
q8_kafka_eo_p50 = [166,
172.7,
185.5,
193.2,
135.6,
256.6]
q8_kafka_nocache_alo_p50 = [115,
110.7,
111.9,
112.7]
q8_kafka_nocache_eo_p50 = [167,
177.1,
190.2,
195.7]
q8_alo_p99 = [291.9,
272.1,
275.5,
276.9,
241.8,
304]
q8_epoch_p99 = [344.3,
295.9,
301.5,
302.6,
309.9,
5165.8]
q8_kafka_alo_p99 = [199.9,
195.1,
236,
196.7,
200.4,
768]
q8_kafka_eo_p99 = [293.1,
295,
311.8,
296.8,
218.1,
1238.8]
q8_kafka_nocache_alo_p99 = [200.1,
196,
246.6,
197.5]
q8_kafka_nocache_eo_p99 = [291.5,
294,
321.5,
299.5]

plt.figure()
plt.plot(in_tp, q8_alo_p50[:-1], label='sys(at least once) p50', color=colors[0])
plt.plot(in_tp, q8_epoch_p50[:-1], label='sys(epoch) p50', color=colors[1])
plt.plot(in_tp, q8_kafka_alo_p50[:-1], label='kafka(at least once) p50', color=colors[2])
plt.plot(in_tp, q8_kafka_eo_p50[:-1], label='kafka(exactly once) p50', color=colors[3])
plt.plot(in_tp, q8_alo_p99[:-1], label='sys(at least once) p99', ls='--', color=colors[0])
plt.plot(in_tp, q8_epoch_p99[:-1], label='sys(epoch) p99', ls='--', color=colors[1])
plt.plot(in_tp, q8_kafka_alo_p99[:-1], label='kafka(at least once) p99', ls='--', color=colors[2])
plt.plot(in_tp, q8_kafka_eo_p99[:-1], label='kafka(exactly once) p99', ls='--', color=colors[3])

plt.xlabel('input throughput(events/s)')
plt.ylabel('event time latency(ms)')
plt.legend(loc=(0, 1.02), ncol=2)
plt.savefig('q8.pdf', bbox_inches='tight')

plt.figure(figsize=(6, 7))
ax1 = plt.subplot(211)
l1, = ax1.plot(in_tp, q8_alo_p50[:-1], label='sys(at least once) p50', color=colors[0])
l2, = ax1.plot(in_tp, q8_kafka_alo_p50[:-1], label='kafka(at least once) p50', color=colors[2])
l3, = ax1.plot(in_tp, q8_alo_p99[:-1], label='sys(at least once) p99', ls='--', color=colors[0])
l4, = ax1.plot(in_tp, q8_kafka_alo_p99[:-1], label='kafka(at least once) p99', ls='--', color=colors[2])
ax2 = plt.subplot(212)
l5, = ax2.plot(in_tp, q8_epoch_p50[:-1], label='sys(epoch) p50', color=colors[1])
l6, = ax2.plot(in_tp, q8_kafka_eo_p50[:-1], label='kafka(exactly once) p50', color=colors[3])
l7, = ax2.plot(in_tp, q8_epoch_p99[:-1], label='sys(epoch) p99', ls='--', color=colors[1])
l8, = ax2.plot(in_tp, q8_kafka_eo_p99[:-1], label='kafka(exactly once) p99', ls='--', color=colors[3])

ax2.set_xlabel('input throughput(events/s)')
ax1.set_ylabel('event time latency(ms)')
ax2.set_ylabel('event time latency(ms)')
ax1.legend(loc=(0, 1.02), ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
plt.savefig('q8_split.pdf', bbox_inches='tight')

# %%
in_per_worker_tp = [1000, 4000, 16000, 64000]
in_tp = [str(i*4) for i in in_per_worker_tp]
q1_alo_p50 = [9.2,
8.8,
9.8,
9.2]
q1_epoch_p50 = [9.1,
9.5,
10.6,
9.5]
q1_kafka_alo_p50 = [7.3,
7,
8,
8.2]
q1_kafka_eo_p50 = [7.3,
7,
8,
8.2]
q1_alo_p99 = [15.2,
15,
15.8,
20.8]
q1_epoch_p99 = [15.1,
15.5,
16.6,
16.6]
q1_kafka_alo_p99 = [12.8,
13.7,
68,
76.1]
q1_kafka_eo_p99 = [14.2,
15.7,
58.7,
94.2]
plt.figure()
plt.plot(in_tp, q1_alo_p50, label='sys(at least once) p50', color=colors[0])
plt.plot(in_tp, q1_epoch_p50, label='sys(epoch) p50', color=colors[1])
plt.plot(in_tp, q1_kafka_alo_p50, label='kafka(at least once) p50', color=colors[2])
plt.plot(in_tp, q1_kafka_eo_p50, label='kafka(exactly once) p50', color=colors[3])
plt.plot(in_tp, q1_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
plt.plot(in_tp, q1_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
plt.plot(in_tp, q1_kafka_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
plt.plot(in_tp, q1_kafka_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

plt.xlabel('input throughput(events/s)')
plt.ylabel('event time latency(ms)')
plt.legend(loc=(0, 1.02), ncol=2)
plt.savefig('q1.pdf', bbox_inches='tight')

plt.figure(figsize=(6, 7))
ax1 = plt.subplot(211)
l1, = ax1.plot(in_tp, q1_alo_p50, label='sys(at least once) p50', color=colors[0])
l2, = ax1.plot(in_tp, q1_kafka_alo_p50, label='kafka(at least once) p50', color=colors[2])
l3, = ax1.plot(in_tp, q1_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
l4, = ax1.plot(in_tp, q1_kafka_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
ax2 = plt.subplot(212)
l5, = ax2.plot(in_tp, q1_epoch_p50, label='sys(epoch) p50', color=colors[1])
l6, = ax2.plot(in_tp, q1_kafka_eo_p50, label='kafka(exactly once) p50', color=colors[3])
l7, = ax2.plot(in_tp, q1_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
l8, = ax2.plot(in_tp, q1_kafka_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

ax2.set_xlabel('input throughput(events/s)')
ax2.set_ylabel('event time latency(ms)')
ax1.set_ylabel('event time latency(ms)')
ax1.legend(loc=(0, 1.02), ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
plt.savefig('q1_split.pdf', bbox_inches='tight')

# %%
in_per_worker_tp = [1000, 4000, 16000, 64000]
in_tp = [str(i*4) for i in in_per_worker_tp]
q2_alo_p50 = [7.9,
9.2,
9.5,
7.9]
q2_epoch_p50 = [8.5,
8.8,
9.8,
8.5]
q2_kafka_alo_p50 = [6.6,
7.2,
7.9,
7.7]
q2_kafka_eo_p50 = [6.8,
7.1,
9.2,
8]
q2_alo_p99 = [13.9,
15.3,
15.8,
16.1]
q2_epoch_p99 = [14.6,
15,
16,
16.3]
q2_kafka_alo_p99 = [12.1,
12.9,
19.4,
21.7]
q2_kafka_eo_p99 = [12.1,
14.8,
34.7,
29.6]
plt.figure()
plt.plot(in_tp, q2_alo_p50, label='sys(at least once) p50', color=colors[0])
plt.plot(in_tp, q2_epoch_p50, label='sys(epoch) p50', color=colors[1])
plt.plot(in_tp, q2_kafka_alo_p50, label='kafka(at least once) p50', color=colors[2])
plt.plot(in_tp, q2_kafka_eo_p50, label='kafka(exactly once) p50', color=colors[3])
plt.plot(in_tp, q2_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
plt.plot(in_tp, q2_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
plt.plot(in_tp, q2_kafka_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
plt.plot(in_tp, q2_kafka_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

plt.xlabel('input throughput(events/s)')
plt.ylabel('event time latency(ms)')
plt.legend(loc=(0, 1.02), ncol=2)
plt.savefig('q2.pdf', bbox_inches='tight')

plt.figure(figsize=(6, 7))
ax1 = plt.subplot(211)
l1, = ax1.plot(in_tp, q2_alo_p50, label='sys(at least once) p50', color=colors[0])
l2, = ax1.plot(in_tp, q2_kafka_alo_p50, label='kafka(at least once) p50', color=colors[2])
l3, = ax1.plot(in_tp, q2_alo_p99, label='sys(at least once) p99', ls='--', color=colors[0])
l4, = ax1.plot(in_tp, q2_kafka_alo_p99, label='kafka(at least once) p99', ls='--', color=colors[2])
ax2 = plt.subplot(212)
l5, = ax2.plot(in_tp, q2_epoch_p50, label='sys(epoch) p50', color=colors[1])
l6, = ax2.plot(in_tp, q2_kafka_eo_p50, label='kafka(exactly once) p50', color=colors[3])
l7, = ax2.plot(in_tp, q2_epoch_p99, label='sys(epoch) p99', ls='--', color=colors[1])
l8, = ax2.plot(in_tp, q2_kafka_eo_p99, label='kafka(exactly once) p99', ls='--', color=colors[3])

ax2.set_xlabel('input throughput(events/s)')
ax1.set_ylabel('event time latency(ms)')
ax2.set_ylabel('event time latency(ms)')
ax1.legend(loc=(0, 1.02), ncol=2, handles=[l1,l2,l3,l4,l5,l6,l7,l8])
plt.savefig('q2_split.pdf', bbox_inches='tight')
